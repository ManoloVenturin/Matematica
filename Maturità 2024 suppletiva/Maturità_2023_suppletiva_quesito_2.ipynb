# %% [markdown]
# # Maturità 2023 (suppletiva) - Quesito 2

# %% [markdown]
# ![testo_quesito_2.png](attachment:testo_quesito_2.png)

# %%
# Toolbox simbolico
from sympy import *

# %%
p = symbols('p', real=True)

# %%
p = simplify("1/6")
p
# Out:
# 1/6

# %%
P1 = binomial(8,3) * p**3 * (1-p)**5
P1
# Out:
# 21875/209952

# %%
N(P1)
# Out:
# 0.104190481633897

# %%
P2 = binomial(7,2) * p**2 * (1-p)**5 * p
P2
# Out:
# 21875/559872

# %%
N(P2)
# Out:
# 0.0390714306127115
