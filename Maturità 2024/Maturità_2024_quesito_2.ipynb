# %% [markdown]
# # Maturità 2024 - Quesito 2

# %% [markdown]
# ![testo_quesito_2.png](attachment:testo_quesito_2.png)

# %%
# Toolbox simbolico
from sympy import *

# %%
p = symbols('p', real=True)

# %%
# Problabilità evento elementare
P_evento = p **2 * (1-p) **3
P_evento
# Out:
# p**2*(1 - p)**3

# %%
# Numero di eventi elementari
N_eventi = binomial(5,2)
N_eventi
# Out:
# 10

# %%
# Probabilità totale di uscita
P_totale = P_evento * N_eventi
P_totale
# Out:
# 10*p**2*(1 - p)**3

# %%
# Derivata prima
P_prime_totale = factor(diff(P_totale, p))
P_prime_totale
# Out:
# -10*p*(p - 1)**2*(5*p - 2)

# %%
# Zeri della derivata prima
pzero = solve(P_prime_totale)
pzero
# Out:
# [0, 2/5, 1]

# %%
p1 = plot(P_totale,(p,0,1), ylim=(-5, 5), title="P")

# %%
p1 = plot(sign(P_prime_totale),(p,0,1), ylim=(-5, 5), title="Segno derivata")
