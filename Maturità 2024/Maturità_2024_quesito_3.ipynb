# %% [markdown]
# # Maturità 2024 - Quesito 3

# %% [markdown]
# ![testo_quesito_3.png](attachment:testo_quesito_3.png)

# %%
# Toolbox simbolico
from sympy import *

# %%
t,r = symbols('t,r', real=True)
x,y,z = symbols('x,y,z', real=True)

# %% [markdown]
# ## Proeizione del punto nel piano

# %%
# Punti A e B
eq_piano = Eq(3*x-2*y+5,0)
display(eq_piano)
P = Array([4,2,1])
P
# Out:
# Eq(3*x - 2*y + 5, 0)
# [4, 2, 1]

# %%
# Coseni direttori del piano
n = Array([3,-2,0])
print_latex(n)
n
# Out:
# \left[\begin{matrix}3 & -2 & 0\end{matrix}\right]
# [3, -2, 0]

# %%
# Scrittura della retta
r = Eq(Array([x,y,z]), P + t*n)
print_latex(r)
r
# Out:
# \left[\begin{matrix}x & y & z\end{matrix}\right] = \left[\begin{matrix}3 t + 4 & 2 - 2 t & 1\end{matrix}\right]
# Eq([x, y, z], [3*t + 4, 2 - 2*t, 1])

# %%
# equazioni da risolvere
eq1 = eq_piano.lhs
display(eq1)

eq2 = r.lhs[0] - r.rhs[0]
display(eq2)

eq3 = r.lhs[1] - r.rhs[1]
display(eq3)

eq4 = r.lhs[2] - r.rhs[2]
display(eq4)
# Out:
# 3*x - 2*y + 5
# -3*t + x - 4
# 2*t + y - 2
# z - 1

# %%
# Trovo t di intersezione
tsol = solve([eq1, eq2, eq3, eq4],[x,y,z,t])
tsol
# Out:
# {x: 1, y: 4, t: -1, z: 1}

# %% [markdown]
# ## Intersezione retta piano

# %%
eq1 = eq_piano.lhs
display(eq1)
# Out:
# 3*x - 2*y + 5

# %%
eq2 = x-y+1
display(eq2)
# Out:
# x - y + 1

# %%
eq3 = z-2
display(eq3)
# Out:
# z - 2

# %%
psol = solve([eq1, eq2, eq3],[x,y,z])
psol
# Out:
# {x: -3, y: -2, z: 2}
